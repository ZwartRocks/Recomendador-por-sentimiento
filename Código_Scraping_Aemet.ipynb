# %% [markdown]
# # 🌦️ AEMET: Descarga climática diaria
#
# Este notebook usa el endpoint de **AEMET OpenData** para descargar datos **diarios** de una **estación (idema)** en bloques de ~6 meses, guarda cada bloque como CSV en una carpeta por ciudad, y luego concatena todo en un único CSV por ciudad.
#
# Lo tenemos que hacer de 6 en 6 meses porque es lo maximo que nos deja descargar AEMET.

# %% [markdown]
# ## 🧰 Intalación

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2025.7.14)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## ⚙️ Configuración
#
# - **Rango temporal**: (2017-01-01 a 2025-12-31.
# - **Chunking**:  **bloques de ~182 días** (≈6 meses) es lo máximo que deja descragar aemet.
# - **Endpoint**: `valores/climatologicos/diarios/datos/fechaini/{...}/fechafin/{...}/estacion/{idema}`

# %%
import os
import time
import glob
import requests
import pandas as pd
from datetime import datetime, timedelta
from typing import List, Dict, Any, Optional

# 🔐 Tu API Key (usa variable de entorno si prefieres)
API_KEY = os.getenv("AEMET_API_KEY", "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJlbGVuYWFlbWhAZ21haWwuY29tIiwianRpIjoiMWMzYThhZWQtNDJiNC00OTdiLThkMmUtNTI4Y2QzYjBkNWY0IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE3NTc3NjY3NTYsInVzZXJJZCI6IjFjM2E4YWVkLTQyYjQtNDk3Yi04ZDJlLTUyOGNkM2IwZDVmNCIsInJvbGUiOiIifQ.S3EPS2nAdEuJYcIth_amTuXws0Eytr-xwIpwJJAX4Ms")

# 🗓️ Rango global (igual al original)
START_DATE = datetime(2017, 1, 1)
END_DATE   = datetime(2025, 12, 31)

# 🏙️ Orden de ciudades solicitado
CITY_ORDER = [
    "Tenerife", "Barcelona", "Madrid", "Malaga",
    "Gran Canaria", "Sevilla", "Valencia", "Palma de Mallorca"
]

# 🛰️ Mapeo ciudad ➜ idema (códigos de estación AEMET)

IDEMA_MAP: Dict[str, Optional[str]] = {
    "Madrid": "3195",
    "Sevilla": "5783",
    "Valencia": "8416Y",
    "Barcelona": "0201D",
    "Tenerife": "C449C",
    "Malaga": "6156X",
    "Gran Canaria": "C649I",
    "Palma de Mallorca": "B228",
}

# 📂 Carpeta base de salida
BASE_DIR = "."

# 🔗 Endpoint (mismo patrón que el original)
ENDPOINT_FMT = (
    "https://opendata.aemet.es/opendata/api/valores/"
    "climatologicos/diarios/datos/fechaini/{fechaini}/fechafin/{fechafin}/estacion/{idema}/"
    "?api_key={API_KEY}"
)

# %% [markdown]
# ## 🔧 Funciones auxiliares

# %%
def get_datos_periodo(idema: str, fecha_ini: datetime, fecha_fin: datetime, reintentos: int = 3):
    """Descarga JSON diario desde AEMET para [fecha_ini, fecha_fin] en una estación (idema)."""
    fechaini = fecha_ini.strftime("%Y-%m-%dT00:00:00UTC")
    fechafin = fecha_fin.strftime("%Y-%m-%dT23:59:59UTC")
    url = ENDPOINT_FMT.format(fechaini=fechaini, fechafin=fechafin, idema=idema, API_KEY=API_KEY)

    for intento in range(reintentos):
        try:
            # Paso 1: pedir URL temporal
            resp = requests.get(url, timeout=30)
            resp.raise_for_status()
            data = resp.json()
            datos_url = data.get("datos")
            if not datos_url:
                return []

            # Paso 2: pedir los datos a la URL temporal
            resp2 = requests.get(datos_url, timeout=60)
            resp2.raise_for_status()
            return resp2.json()
        except Exception as e:
            print(f"⚠️ Error {intento+1}/{reintentos} en {fecha_ini.date()}-{fecha_fin.date()}: {e}")
            time.sleep(5)
    return []


def slugify(name: str) -> str:
    s = name.lower()
    s = s.replace(" ", "_").replace("á", "a").replace("é", "e").replace("í", "i").replace("ó", "o").replace("ú", "u").replace("ü", "u").replace("ñ", "n")
    s = s.replace("-", "_")
    return s

# %% [markdown]
# ## 🕸️ Descarga por ciudad (misma mecánica del original)
#
# - Crea una carpeta `datos_<slug>` por ciudad.
# - Descarga en bloques de ~182 días.
# - Guarda cada bloque como CSV con el nombre `<slug>_<inicio>_<fin>.csv`.

# %%
def descargar_ciudad(ciudad: str, idema: str, start: datetime = START_DATE, end: datetime = END_DATE) -> str:
    slug = slugify(ciudad)
    carpeta = os.path.join(BASE_DIR, f"datos_{slug}")
    os.makedirs(carpeta, exist_ok=True)

    current = start
    while current < end:
        next_date = current + timedelta(days=182)  # ~6 meses
        if next_date > end:
            next_date = end

        print(f"⏳ {ciudad}: {current.date()} → {next_date.date()}")
        datos = get_datos_periodo(idema, current, next_date)

        if datos:
            df = pd.DataFrame(datos)
            fname = os.path.join(carpeta, f"{slug}_{current.date()}_{next_date.date()}.csv")
            df.to_csv(fname, index=False)
            print(f"✅ Guardado {fname} ({len(df)} registros)")
        else:
            print(f"❌ Sin datos {current.date()} → {next_date.date()}")

        current = next_date + timedelta(days=1)

    return carpeta

# %% [markdown]
# ## 🧩 Unificación de CSVs por ciudad

# %%
def unificar_ciudad(ciudad: str) -> Optional[str]:
    slug = slugify(ciudad)
    carpeta = os.path.join(BASE_DIR, f"datos_{slug}")
    if not os.path.isdir(carpeta):
        print(f"⚠️ Carpeta no encontrada: {carpeta}")
        return None

    archivos = glob.glob(os.path.join(carpeta, "*.csv"))
    print(f"📚 {ciudad}: {len(archivos)} archivos CSV encontrados")
    if not archivos:
        return None

    dfs = []
    for path in archivos:
        try:
            dfs.append(pd.read_csv(path))
        except Exception as e:
            print(f"⚠️ Error leyendo {path}: {e}")

    if not dfs:
        print(f"⚠️ No se pudieron leer CSVs para {ciudad}")
        return None

    df_final = pd.concat(dfs, ignore_index=True)
    out_path = os.path.join(BASE_DIR, f"datos_{slug}_unificado.csv")
    df_final.to_csv(out_path, index=False, encoding="utf-8")
    print(f"🎉 {ciudad}: unificado → {out_path} ({len(df_final)} filas)")
    return out_path

# %% [markdown]
# ## ▶️ Ejecutar para las 8 ciudades
#
# Se recorre el orden solicitado.

# %%
def run_all_cities(city_order = CITY_ORDER, idema_map = IDEMA_MAP):
    resultados = []
    for city in city_order:
        idema = idema_map.get(city)
        if not idema:
            print(f"🛈 Sin idema para '{city}'. Añádelo en IDEMA_MAP y vuelve a ejecutar.")
            resultados.append((city, None, None))
            continue

        try:
            carpeta = descargar_ciudad(city, idema)
            unificado = unificar_ciudad(city)
            resultados.append((city, carpeta, unificado))
        except Exception as e:
            print(f"❌ Error con {city}: {e}")
            resultados.append((city, None, None))
    return resultados


run_all_cities()
# Out:
# ⏳ Tenerife: 2017-01-01 → 2017-07-02
# ✅ Guardado ./datos_tenerife/tenerife_2017-01-01_2017-07-02.csv (183 registros)
# ⏳ Tenerife: 2017-07-03 → 2018-01-01
# ✅ Guardado ./datos_tenerife/tenerife_2017-07-03_2018-01-01.csv (183 registros)
# ⏳ Tenerife: 2018-01-02 → 2018-07-03
# ⚠️ Error 1/3 en 2018-01-02-2018-07-03: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Error 2/3 en 2018-01-02-2018-07-03: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ✅ Guardado ./datos_tenerife/tenerife_2018-01-02_2018-07-03.csv (183 registros)
# ⏳ Tenerife: 2018-07-04 → 2019-01-02
# ✅ Guardado ./datos_tenerife/tenerife_2018-07-04_2019-01-02.csv (183 registros)
# ⏳ Tenerife: 2019-01-03 → 2019-07-04
# ✅ Guardado ./datos_tenerife/tenerife_2019-01-03_2019-07-04.csv (183 registros)
# ⏳ Tenerife: 2019-07-05 → 2020-01-03
# ✅ Guardado ./datos_tenerife/tenerife_2019-07-05_2020-01-03.csv (183 registros)
# ⏳ Tenerife: 2020-01-04 → 2020-07-04
# ✅ Guardado ./datos_tenerife/tenerife_2020-01-04_2020-07-04.csv (183 registros)
# ⏳ Tenerife: 2020-07-05 → 2021-01-03
# ✅ Guardado ./datos_tenerife/tenerife_2020-07-05_2021-01-03.csv (183 registros)
# ⏳ Tenerife: 2021-01-04 → 2021-07-05
# ✅ Guardado ./datos_tenerife/tenerife_2021-01-04_2021-07-05.csv (183 registros)
# ⏳ Tenerife: 2021-07-06 → 2022-01-04
# ✅ Guardado ./datos_tenerife/tenerife_2021-07-06_2022-01-04.csv (183 registros)
# ⏳ Tenerife: 2022-01-05 → 2022-07-06
# ✅ Guardado ./datos_tenerife/tenerife_2022-01-05_2022-07-06.csv (183 registros)
# ⏳ Tenerife: 2022-07-07 → 2023-01-05
# ✅ Guardado ./datos_tenerife/tenerife_2022-07-07_2023-01-05.csv (183 registros)
# ⏳ Tenerife: 2023-01-06 → 2023-07-07
# ✅ Guardado ./datos_tenerife/tenerife_2023-01-06_2023-07-07.csv (183 registros)
# ⏳ Tenerife: 2023-07-08 → 2024-01-06
# ⚠️ Error 1/3 en 2023-07-08-2024-01-06: HTTPSConnectionPool(host='opendata.aemet.es', port=443): Read timed out. (read timeout=30)
# ⚠️ Error 2/3 en 2023-07-08-2024-01-06: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Error 3/3 en 2023-07-08-2024-01-06: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ❌ Sin datos 2023-07-08 → 2024-01-06
# ⏳ Tenerife: 2024-01-07 → 2024-07-07
# ✅ Guardado ./datos_tenerife/tenerife_2024-01-07_2024-07-07.csv (183 registros)
# ⏳ Tenerife: 2024-07-08 → 2025-01-06
# ✅ Guardado ./datos_tenerife/tenerife_2024-07-08_2025-01-06.csv (183 registros)
# ⏳ Tenerife: 2025-01-07 → 2025-07-08
# ✅ Guardado ./datos_tenerife/tenerife_2025-01-07_2025-07-08.csv (183 registros)
# ⏳ Tenerife: 2025-07-09 → 2025-12-31
# ✅ Guardado ./datos_tenerife/tenerife_2025-07-09_2025-12-31.csv (65 registros)
# 📚 Tenerife: 17 archivos CSV encontrados
# 🎉 Tenerife: unificado → ./datos_tenerife_unificado.csv (2993 filas)
# ⏳ Barcelona: 2017-01-01 → 2017-07-02
# ✅ Guardado ./datos_barcelona/barcelona_2017-01-01_2017-07-02.csv (183 registros)
# ⏳ Barcelona: 2017-07-03 → 2018-01-01
# ✅ Guardado ./datos_barcelona/barcelona_2017-07-03_2018-01-01.csv (183 registros)
# ⏳ Barcelona: 2018-01-02 → 2018-07-03
# ✅ Guardado ./datos_barcelona/barcelona_2018-01-02_2018-07-03.csv (183 registros)
# ⏳ Barcelona: 2018-07-04 → 2019-01-02
# ✅ Guardado ./datos_barcelona/barcelona_2018-07-04_2019-01-02.csv (183 registros)
# ⏳ Barcelona: 2019-01-03 → 2019-07-04
# ✅ Guardado ./datos_barcelona/barcelona_2019-01-03_2019-07-04.csv (183 registros)
# ⏳ Barcelona: 2019-07-05 → 2020-01-03
# ✅ Guardado ./datos_barcelona/barcelona_2019-07-05_2020-01-03.csv (183 registros)
# ⏳ Barcelona: 2020-01-04 → 2020-07-04
# ✅ Guardado ./datos_barcelona/barcelona_2020-01-04_2020-07-04.csv (183 registros)
# ⏳ Barcelona: 2020-07-05 → 2021-01-03
# ✅ Guardado ./datos_barcelona/barcelona_2020-07-05_2021-01-03.csv (183 registros)
# ⏳ Barcelona: 2021-01-04 → 2021-07-05
# ✅ Guardado ./datos_barcelona/barcelona_2021-01-04_2021-07-05.csv (183 registros)
# ⏳ Barcelona: 2021-07-06 → 2022-01-04
# ✅ Guardado ./datos_barcelona/barcelona_2021-07-06_2022-01-04.csv (183 registros)
# ⏳ Barcelona: 2022-01-05 → 2022-07-06
# ✅ Guardado ./datos_barcelona/barcelona_2022-01-05_2022-07-06.csv (177 registros)
# ⏳ Barcelona: 2022-07-07 → 2023-01-05
# ❌ Sin datos 2022-07-07 → 2023-01-05
# ⏳ Barcelona: 2023-01-06 → 2023-07-07
# ✅ Guardado ./datos_barcelona/barcelona_2023-01-06_2023-07-07.csv (63 registros)
# ⏳ Barcelona: 2023-07-08 → 2024-01-06
# ✅ Guardado ./datos_barcelona/barcelona_2023-07-08_2024-01-06.csv (183 registros)
# ⏳ Barcelona: 2024-01-07 → 2024-07-07
# ✅ Guardado ./datos_barcelona/barcelona_2024-01-07_2024-07-07.csv (183 registros)
# ⏳ Barcelona: 2024-07-08 → 2025-01-06
# ✅ Guardado ./datos_barcelona/barcelona_2024-07-08_2025-01-06.csv (183 registros)
# ⏳ Barcelona: 2025-01-07 → 2025-07-08
# ⚠️ Error 1/3 en 2025-01-07-2025-07-08: HTTPSConnectionPool(host='opendata.aemet.es', port=443): Max retries exceeded with url: /opendata/sh/fa27c59b (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x12d060920>, 'Connection to opendata.aemet.es timed out. (connect timeout=60)'))
# ✅ Guardado ./datos_barcelona/barcelona_2025-01-07_2025-07-08.csv (183 registros)
# ⏳ Barcelona: 2025-07-09 → 2025-12-31
# ✅ Guardado ./datos_barcelona/barcelona_2025-07-09_2025-12-31.csv (65 registros)
# 📚 Barcelona: 17 archivos CSV encontrados
# 🎉 Barcelona: unificado → ./datos_barcelona_unificado.csv (2867 filas)
# ⏳ Madrid: 2017-01-01 → 2017-07-02
# ✅ Guardado ./datos_madrid/madrid_2017-01-01_2017-07-02.csv (183 registros)
# ⏳ Madrid: 2017-07-03 → 2018-01-01
# ✅ Guardado ./datos_madrid/madrid_2017-07-03_2018-01-01.csv (183 registros)
# ⏳ Madrid: 2018-01-02 → 2018-07-03
# ✅ Guardado ./datos_madrid/madrid_2018-01-02_2018-07-03.csv (183 registros)
# ⏳ Madrid: 2018-07-04 → 2019-01-02
# ✅ Guardado ./datos_madrid/madrid_2018-07-04_2019-01-02.csv (183 registros)
# ⏳ Madrid: 2019-01-03 → 2019-07-04
# ✅ Guardado ./datos_madrid/madrid_2019-01-03_2019-07-04.csv (183 registros)
# ⏳ Madrid: 2019-07-05 → 2020-01-03
# ✅ Guardado ./datos_madrid/madrid_2019-07-05_2020-01-03.csv (183 registros)
# ⏳ Madrid: 2020-01-04 → 2020-07-04
# ✅ Guardado ./datos_madrid/madrid_2020-01-04_2020-07-04.csv (183 registros)
# ⏳ Madrid: 2020-07-05 → 2021-01-03
# ✅ Guardado ./datos_madrid/madrid_2020-07-05_2021-01-03.csv (183 registros)
# ⏳ Madrid: 2021-01-04 → 2021-07-05
# ✅ Guardado ./datos_madrid/madrid_2021-01-04_2021-07-05.csv (183 registros)
# ⏳ Madrid: 2021-07-06 → 2022-01-04
# ✅ Guardado ./datos_madrid/madrid_2021-07-06_2022-01-04.csv (183 registros)
# ⏳ Madrid: 2022-01-05 → 2022-07-06
# ✅ Guardado ./datos_madrid/madrid_2022-01-05_2022-07-06.csv (182 registros)
# ⏳ Madrid: 2022-07-07 → 2023-01-05
# ✅ Guardado ./datos_madrid/madrid_2022-07-07_2023-01-05.csv (183 registros)
# ⏳ Madrid: 2023-01-06 → 2023-07-07
# ✅ Guardado ./datos_madrid/madrid_2023-01-06_2023-07-07.csv (183 registros)
# ⏳ Madrid: 2023-07-08 → 2024-01-06
# ✅ Guardado ./datos_madrid/madrid_2023-07-08_2024-01-06.csv (183 registros)
# ⏳ Madrid: 2024-01-07 → 2024-07-07
# ✅ Guardado ./datos_madrid/madrid_2024-01-07_2024-07-07.csv (183 registros)
# ⏳ Madrid: 2024-07-08 → 2025-01-06
# ✅ Guardado ./datos_madrid/madrid_2024-07-08_2025-01-06.csv (183 registros)
# ⏳ Madrid: 2025-01-07 → 2025-07-08
# ✅ Guardado ./datos_madrid/madrid_2025-01-07_2025-07-08.csv (183 registros)
# ⏳ Madrid: 2025-07-09 → 2025-12-31
# ✅ Guardado ./datos_madrid/madrid_2025-07-09_2025-12-31.csv (65 registros)
# 📚 Madrid: 18 archivos CSV encontrados
# 🎉 Madrid: unificado → ./datos_madrid_unificado.csv (3175 filas)
# ⏳ Malaga: 2017-01-01 → 2017-07-02
# ✅ Guardado ./datos_malaga/malaga_2017-01-01_2017-07-02.csv (183 registros)
# ⏳ Malaga: 2017-07-03 → 2018-01-01
# ✅ Guardado ./datos_malaga/malaga_2017-07-03_2018-01-01.csv (183 registros)
# ⏳ Malaga: 2018-01-02 → 2018-07-03
# ⚠️ Error 1/3 en 2018-01-02-2018-07-03: 429 Client Error: Too Many Requests for url: https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2018-01-02T00:00:00UTC/fechafin/2018-07-03T23:59:59UTC/estacion/6156X/?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJlbGVuYWFlbWhAZ21haWwuY29tIiwianRpIjoiMWMzYThhZWQtNDJiNC00OTdiLThkMmUtNTI4Y2QzYjBkNWY0IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE3NTc3NjY3NTYsInVzZXJJZCI6IjFjM2E4YWVkLTQyYjQtNDk3Yi04ZDJlLTUyOGNkM2IwZDVmNCIsInJvbGUiOiIifQ.S3EPS2nAdEuJYcIth_amTuXws0Eytr-xwIpwJJAX4Ms
# ⚠️ Error 2/3 en 2018-01-02-2018-07-03: 429 Client Error: Too Many Requests for url: https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2018-01-02T00:00:00UTC/fechafin/2018-07-03T23:59:59UTC/estacion/6156X/?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJlbGVuYWFlbWhAZ21haWwuY29tIiwianRpIjoiMWMzYThhZWQtNDJiNC00OTdiLThkMmUtNTI4Y2QzYjBkNWY0IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE3NTc3NjY3NTYsInVzZXJJZCI6IjFjM2E4YWVkLTQyYjQtNDk3Yi04ZDJlLTUyOGNkM2IwZDVmNCIsInJvbGUiOiIifQ.S3EPS2nAdEuJYcIth_amTuXws0Eytr-xwIpwJJAX4Ms
# ⚠️ Error 3/3 en 2018-01-02-2018-07-03: 429 Client Error: Too Many Requests for url: https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2018-01-02T00:00:00UTC/fechafin/2018-07-03T23:59:59UTC/estacion/6156X/?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJlbGVuYWFlbWhAZ21haWwuY29tIiwianRpIjoiMWMzYThhZWQtNDJiNC00OTdiLThkMmUtNTI4Y2QzYjBkNWY0IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE3NTc3NjY3NTYsInVzZXJJZCI6IjFjM2E4YWVkLTQyYjQtNDk3Yi04ZDJlLTUyOGNkM2IwZDVmNCIsInJvbGUiOiIifQ.S3EPS2nAdEuJYcIth_amTuXws0Eytr-xwIpwJJAX4Ms
# ❌ Sin datos 2018-01-02 → 2018-07-03
# ⏳ Malaga: 2018-07-04 → 2019-01-02
# ⚠️ Error 1/3 en 2018-07-04-2019-01-02: HTTPSConnectionPool(host='opendata.aemet.es', port=443): Max retries exceeded with url: /opendata/api/valores/climatologicos/diarios/datos/fechaini/2018-07-04T00:00:00UTC/fechafin/2019-01-02T23:59:59UTC/estacion/6156X/?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJlbGVuYWFlbWhAZ21haWwuY29tIiwianRpIjoiMWMzYThhZWQtNDJiNC00OTdiLThkMmUtNTI4Y2QzYjBkNWY0IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE3NTc3NjY3NTYsInVzZXJJZCI6IjFjM2E4YWVkLTQyYjQtNDk3Yi04ZDJlLTUyOGNkM2IwZDVmNCIsInJvbGUiOiIifQ.S3EPS2nAdEuJYcIth_amTuXws0Eytr-xwIpwJJAX4Ms (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x12d0262a0>, 'Connection to opendata.aemet.es timed out. (connect timeout=30)'))
# ✅ Guardado ./datos_malaga/malaga_2018-07-04_2019-01-02.csv (183 registros)
# ⏳ Malaga: 2019-01-03 → 2019-07-04
# ✅ Guardado ./datos_malaga/malaga_2019-01-03_2019-07-04.csv (183 registros)
# ⏳ Malaga: 2019-07-05 → 2020-01-03
# ✅ Guardado ./datos_malaga/malaga_2019-07-05_2020-01-03.csv (183 registros)
# ⏳ Malaga: 2020-01-04 → 2020-07-04
# ✅ Guardado ./datos_malaga/malaga_2020-01-04_2020-07-04.csv (183 registros)
# ⏳ Malaga: 2020-07-05 → 2021-01-03
# ✅ Guardado ./datos_malaga/malaga_2020-07-05_2021-01-03.csv (183 registros)
# ⏳ Malaga: 2021-01-04 → 2021-07-05
# ✅ Guardado ./datos_malaga/malaga_2021-01-04_2021-07-05.csv (183 registros)
# ⏳ Malaga: 2021-07-06 → 2022-01-04
# ✅ Guardado ./datos_malaga/malaga_2021-07-06_2022-01-04.csv (183 registros)
# ⏳ Malaga: 2022-01-05 → 2022-07-06
# ✅ Guardado ./datos_malaga/malaga_2022-01-05_2022-07-06.csv (183 registros)
# ⏳ Malaga: 2022-07-07 → 2023-01-05
# ✅ Guardado ./datos_malaga/malaga_2022-07-07_2023-01-05.csv (183 registros)
# ⏳ Malaga: 2023-01-06 → 2023-07-07
# ✅ Guardado ./datos_malaga/malaga_2023-01-06_2023-07-07.csv (183 registros)
# ⏳ Malaga: 2023-07-08 → 2024-01-06
# ✅ Guardado ./datos_malaga/malaga_2023-07-08_2024-01-06.csv (183 registros)
# ⏳ Malaga: 2024-01-07 → 2024-07-07
# ✅ Guardado ./datos_malaga/malaga_2024-01-07_2024-07-07.csv (183 registros)
# ⏳ Malaga: 2024-07-08 → 2025-01-06
# ✅ Guardado ./datos_malaga/malaga_2024-07-08_2025-01-06.csv (183 registros)
# ⏳ Malaga: 2025-01-07 → 2025-07-08
# ✅ Guardado ./datos_malaga/malaga_2025-01-07_2025-07-08.csv (183 registros)
# ⏳ Malaga: 2025-07-09 → 2025-12-31
# ✅ Guardado ./datos_malaga/malaga_2025-07-09_2025-12-31.csv (65 registros)
# 📚 Malaga: 17 archivos CSV encontrados
# 🎉 Malaga: unificado → ./datos_malaga_unificado.csv (2993 filas)
# ⏳ Gran Canaria: 2017-01-01 → 2017-07-02
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2017-01-01_2017-07-02.csv (183 registros)
# ⏳ Gran Canaria: 2017-07-03 → 2018-01-01
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2017-07-03_2018-01-01.csv (183 registros)
# ⏳ Gran Canaria: 2018-01-02 → 2018-07-03
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2018-01-02_2018-07-03.csv (183 registros)
# ⏳ Gran Canaria: 2018-07-04 → 2019-01-02
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2018-07-04_2019-01-02.csv (183 registros)
# ⏳ Gran Canaria: 2019-01-03 → 2019-07-04
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2019-01-03_2019-07-04.csv (183 registros)
# ⏳ Gran Canaria: 2019-07-05 → 2020-01-03
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2019-07-05_2020-01-03.csv (183 registros)
# ⏳ Gran Canaria: 2020-01-04 → 2020-07-04
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2020-01-04_2020-07-04.csv (183 registros)
# ⏳ Gran Canaria: 2020-07-05 → 2021-01-03
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2020-07-05_2021-01-03.csv (183 registros)
# ⏳ Gran Canaria: 2021-01-04 → 2021-07-05
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2021-01-04_2021-07-05.csv (183 registros)
# ⏳ Gran Canaria: 2021-07-06 → 2022-01-04
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2021-07-06_2022-01-04.csv (183 registros)
# ⏳ Gran Canaria: 2022-01-05 → 2022-07-06
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2022-01-05_2022-07-06.csv (183 registros)
# ⏳ Gran Canaria: 2022-07-07 → 2023-01-05
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2022-07-07_2023-01-05.csv (183 registros)
# ⏳ Gran Canaria: 2023-01-06 → 2023-07-07
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2023-01-06_2023-07-07.csv (183 registros)
# ⏳ Gran Canaria: 2023-07-08 → 2024-01-06
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2023-07-08_2024-01-06.csv (183 registros)
# ⏳ Gran Canaria: 2024-01-07 → 2024-07-07
# ⚠️ Error 1/3 en 2024-01-07-2024-07-07: HTTPSConnectionPool(host='opendata.aemet.es', port=443): Read timed out.
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2024-01-07_2024-07-07.csv (183 registros)
# ⏳ Gran Canaria: 2024-07-08 → 2025-01-06
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2024-07-08_2025-01-06.csv (183 registros)
# ⏳ Gran Canaria: 2025-01-07 → 2025-07-08
# ⚠️ Error 1/3 en 2025-01-07-2025-07-08: HTTPSConnectionPool(host='opendata.aemet.es', port=443): Read timed out. (read timeout=30)
# ⚠️ Error 2/3 en 2025-01-07-2025-07-08: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Error 3/3 en 2025-01-07-2025-07-08: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ❌ Sin datos 2025-01-07 → 2025-07-08
# ⏳ Gran Canaria: 2025-07-09 → 2025-12-31
# ⚠️ Error 1/3 en 2025-07-09-2025-12-31: 500 Server Error: Internal Server Error for url: https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2025-07-09T00:00:00UTC/fechafin/2025-12-31T23:59:59UTC/estacion/C649I/?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJlbGVuYWFlbWhAZ21haWwuY29tIiwianRpIjoiMWMzYThhZWQtNDJiNC00OTdiLThkMmUtNTI4Y2QzYjBkNWY0IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE3NTc3NjY3NTYsInVzZXJJZCI6IjFjM2E4YWVkLTQyYjQtNDk3Yi04ZDJlLTUyOGNkM2IwZDVmNCIsInJvbGUiOiIifQ.S3EPS2nAdEuJYcIth_amTuXws0Eytr-xwIpwJJAX4Ms
# ✅ Guardado ./datos_gran_canaria/gran_canaria_2025-07-09_2025-12-31.csv (65 registros)
# 📚 Gran Canaria: 17 archivos CSV encontrados
# 🎉 Gran Canaria: unificado → ./datos_gran_canaria_unificado.csv (2993 filas)
# ⏳ Seville: 2017-01-01 → 2017-07-02
# ✅ Guardado ./datos_seville/seville_2017-01-01_2017-07-02.csv (183 registros)
# ⏳ Seville: 2017-07-03 → 2018-01-01
# ✅ Guardado ./datos_seville/seville_2017-07-03_2018-01-01.csv (183 registros)
# ⏳ Seville: 2018-01-02 → 2018-07-03
# ✅ Guardado ./datos_seville/seville_2018-01-02_2018-07-03.csv (183 registros)
# ⏳ Seville: 2018-07-04 → 2019-01-02
# ✅ Guardado ./datos_seville/seville_2018-07-04_2019-01-02.csv (183 registros)
# ⏳ Seville: 2019-01-03 → 2019-07-04
# ✅ Guardado ./datos_seville/seville_2019-01-03_2019-07-04.csv (183 registros)
# ⏳ Seville: 2019-07-05 → 2020-01-03
# ✅ Guardado ./datos_seville/seville_2019-07-05_2020-01-03.csv (183 registros)
# ⏳ Seville: 2020-01-04 → 2020-07-04
# ✅ Guardado ./datos_seville/seville_2020-01-04_2020-07-04.csv (183 registros)
# ⏳ Seville: 2020-07-05 → 2021-01-03
# ✅ Guardado ./datos_seville/seville_2020-07-05_2021-01-03.csv (183 registros)
# ⏳ Seville: 2021-01-04 → 2021-07-05
# ✅ Guardado ./datos_seville/seville_2021-01-04_2021-07-05.csv (183 registros)
# ⏳ Seville: 2021-07-06 → 2022-01-04
# ✅ Guardado ./datos_seville/seville_2021-07-06_2022-01-04.csv (183 registros)
# ⏳ Seville: 2022-01-05 → 2022-07-06
# ✅ Guardado ./datos_seville/seville_2022-01-05_2022-07-06.csv (183 registros)
# ⏳ Seville: 2022-07-07 → 2023-01-05
# ✅ Guardado ./datos_seville/seville_2022-07-07_2023-01-05.csv (183 registros)
# ⏳ Seville: 2023-01-06 → 2023-07-07
# ✅ Guardado ./datos_seville/seville_2023-01-06_2023-07-07.csv (183 registros)
# ⏳ Seville: 2023-07-08 → 2024-01-06
# ✅ Guardado ./datos_seville/seville_2023-07-08_2024-01-06.csv (183 registros)
# ⏳ Seville: 2024-01-07 → 2024-07-07
# ✅ Guardado ./datos_seville/seville_2024-01-07_2024-07-07.csv (183 registros)
# ⏳ Seville: 2024-07-08 → 2025-01-06
# ✅ Guardado ./datos_seville/seville_2024-07-08_2025-01-06.csv (183 registros)
# ⏳ Seville: 2025-01-07 → 2025-07-08
# ✅ Guardado ./datos_seville/seville_2025-01-07_2025-07-08.csv (183 registros)
# ⏳ Seville: 2025-07-09 → 2025-12-31
# ✅ Guardado ./datos_seville/seville_2025-07-09_2025-12-31.csv (65 registros)
# 📚 Seville: 18 archivos CSV encontrados
# 🎉 Seville: unificado → ./datos_seville_unificado.csv (3176 filas)
# ⏳ Valencia: 2017-01-01 → 2017-07-02
# ✅ Guardado ./datos_valencia/valencia_2017-01-01_2017-07-02.csv (183 registros)
# ⏳ Valencia: 2017-07-03 → 2018-01-01
