# %%
import pandas as pd

# %%
getyourguide_df = pd.read_csv('tripadvisor_reviews_unificado.csv')
getyourguide_df.head()
# Out:
#                                           Titulo  \
# 0  Paseos En Camello Por Las Dunas De Maspalomas
# 1  Paseos En Camello Por Las Dunas De Maspalomas
# 2  Paseos En Camello Por Las Dunas De Maspalomas
# 3  Paseos En Camello Por Las Dunas De Maspalomas
# 4  Paseos En Camello Por Las Dunas De Maspalomas
#
#                                           Comentario       Fecha  \
# 0  Una experiencia muy buena y sobre todo al rese...  2025-04-23
# 1  Magnifica experiencia, personal muy amable y a...  2025-04-23
# 2  El dia que teniamos reservado hizo malisimo, l...  2025-04-23
# 3  Muy buen tour, una nueva experiencia. Excelent...  2025-04-23
# 4  Es lo peor que puedes hacer estas fomentando e...  2024-12-23
#
#          Ciudad Experiencia       Fuente
# 0  Gran Canaria        Tour  Tripadvisor
# 1  Gran Canaria        Tour  Tripadvisor
# 2  Gran Canaria        Tour  Tripadvisor
# 3  Gran Canaria        Tour  Tripadvisor
# 4  Gran Canaria        Tour  Tripadvisor

# %%
getyourguide_df['Texto'] = getyourguide_df['Titulo'] + " " + getyourguide_df['Comentario']

# %%
getyourguide_df = getyourguide_df.drop(columns = ['Titulo', 'Comentario'])

# %%
getyourguide_df = getyourguide_df[['Texto', 'Ciudad', 'Experiencia', 'Fecha', 'Fuente']]

# %%
getyourguide_df
# Out:
#                                                     Texto        Ciudad  \
# 0       Paseos En Camello Por Las Dunas De Maspalomas ...  Gran Canaria
# 1       Paseos En Camello Por Las Dunas De Maspalomas ...  Gran Canaria
# 2       Paseos En Camello Por Las Dunas De Maspalomas ...  Gran Canaria
# 3       Paseos En Camello Por Las Dunas De Maspalomas ...  Gran Canaria
# 4       Paseos En Camello Por Las Dunas De Maspalomas ...  Gran Canaria
# ...                                                   ...           ...
# 157454  Excursion De 2 Dias De Cordoba Desde Sevilla, ...       Sevilla
# 157455  Excursion De 2 Dias De Cordoba Desde Sevilla, ...       Sevilla
# 157456  Excursion De 2 Dias De Cordoba Desde Sevilla, ...       Sevilla
# 157457  Excursion De 2 Dias De Cordoba Desde Sevilla, ...       Sevilla
# 157458  Spa Balneario En Sevilla Oasis Gold El equipo ...       Sevilla
#
#         Experiencia       Fecha       Fuente
# 0              Tour  2025-04-23  Tripadvisor
# ...

# %%
getyourguide_df.to_csv('tripadvisor.csv', index=False)
